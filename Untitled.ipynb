# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# data = pd.read_csv('y_total_with_runs.csv')

# %%
sub = pd.read_csv('submission.csv')
hybrid = pd.read_csv('Hybrid_Classified.csv')

sub = sub.rename(columns = {'surface':'surfacesub'})
hybrid = hybrid.rename(columns = {'surface':'surfacehybrid'})

print ("Submission data is ready")
# Out:
# Submission data is ready

# %%
subtest = pd.concat([sub['series_id'], sub['surfacesub'], hybrid['surfacehybrid']], axis=1)
subtest
# Out:
#    series_id  surfacesub           surfacehybrid
# 0          0       tiled  hard_tiles_large_space
# 1          1        wood                concrete
# 2          2       tiled                   tiled
# 3          3      carpet                  carpet
# 4          4  soft_tiles              soft_tiles

# %%
subtest
# Out:
#       series_id              surfacesub           surfacehybrid
# 0             0                   tiled  hard_tiles_large_space
# 1             1                    wood                concrete
# 2             2                   tiled                   tiled
# 3             3                  carpet                  carpet
# 4             4              soft_tiles              soft_tiles
# 5             5                concrete                concrete
# 6             6                soft_pvc                soft_pvc
# 7             7  hard_tiles_large_space  hard_tiles_large_space
# 8             8                    wood                    wood
# 9             9                    wood                soft_pvc
# 10           10                soft_pvc                   tiled
# 11           11                   tiled                    wood
# 12           12                    wood              soft_tiles
# 13           13              soft_tiles                    wood
# ...

# %%
differents = []
for i in range (0,subtest.shape[0]): 
    labels = list(subtest.iloc[i,1:])
    result = len(set(labels))>1
    if result:
        differents.append((i, str(labels)))
        
differents = pd.DataFrame(differents, columns=['idx','group']) 
differents.head()
# Out:
#    idx                                group
# 0    0  ['tiled', 'hard_tiles_large_space']
# 1    1                 ['wood', 'concrete']
# 2    9                 ['wood', 'soft_pvc']
# 3   10                ['soft_pvc', 'tiled']
# 4   11                    ['tiled', 'wood']

# %%
differents['count'].sum()
# Out:
# 3297

# %%
differents['group'].nunique()
# Out:
# 66

# %%
differents['count'] = differents.groupby('group')['group'].transform('count')
differents = differents.sort_values(by=['count'], ascending=False)
differents = differents.drop(['idx'],axis=1)
differents = differents.drop_duplicates()

# %%
differents.head(10)
# Out:
#                               group  count
# 1648       ['concrete', 'soft_pvc']    157
# 1156       ['soft_pvc', 'concrete']    131
# 714            ['wood', 'soft_pvc']    128
# 1279           ['concrete', 'wood']    111
# 2128           ['soft_pvc', 'wood']     93
# 673            ['wood', 'concrete']     91
# 503   ['fine_concrete', 'soft_pvc']     90
# 1265  ['concrete', 'fine_concrete']     87
# 3217     ['soft_tiles', 'soft_pvc']     83
# 2339     ['soft_pvc', 'soft_tiles']     83

# %%
# x = 0
# groups = []

# for group in data['run_id']:
#     groups.append(data[data['run_id']==x])
#     x += 1

len(groups[151])
# Out:
# 26

# %%
groups[106]
# Out:
#       series_id surface  run_id  run_pos
# 4868       4868   empty     106        1
# 5110       5110   empty     106        0
# 5771       5771   empty     106        4
# 6089       6089   empty     106        3
# 7074       7074   empty     106        2

# %%
groups[99]['surface'] = 'concrete'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[87]['surface'] = 'soft_tiles'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[86]['surface'] = 'carpet'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[5]['surface'] = 'hard_tiles'

# %%
groups[78]['surface'] = 'hard_tiles_large_space'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[76]['surface'] = 'soft_pvc'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[101]['surface'] = 'fine_concrete'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[77]['surface'] = 'wood'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
groups[89]['surface'] = 'tiled'
# Out:
# c:\users\doomb\anaconda3\envs\capstone2\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
x = 0
groups = []

for group in data['run_id']:
    groups.append(data[data['run_id']==x])
    x += 1

# %%
data
# Out:
#       series_id        surface  run_id  run_pos
# 0             0  fine_concrete     101      159
# 1             1  fine_concrete      24       14
# 2             2  fine_concrete       5        4
# 3             3  fine_concrete      24       42
# 4             4  fine_concrete      87      164
# 5             5  fine_concrete     148      128
# 6             6  fine_concrete      18       26
# 7             7  fine_concrete      24       49
# 8             8  fine_concrete       6       13
# 9             9  fine_concrete     148       93
# 10           10  fine_concrete      11      149
# 11           11  fine_concrete     148      136
# 12           12  fine_concrete     141       25
# 13           13  fine_concrete     141       29
# 14           14  fine_concrete      96      116
# 15           15  fine_concrete     136       56
# 16           16  fine_concrete     136       76
# 17           17  fine_concrete      22       43
# 18           18  fine_concrete      21       75
# ...

# %%
data['surface'][0]
# Out:
# 'fine_concrete'

# %%
data[data['run_id']==0]['surface']
# Out:
# 19      soft_tiles
# 24      soft_tiles
# 30      soft_tiles
# 31      soft_tiles
# 52      soft_tiles
# 80      soft_tiles
# 88      soft_tiles
# 106     soft_tiles
# 114     soft_tiles
# 129     soft_tiles
# 135     soft_tiles
# 136     soft_tiles
# 137     soft_tiles
# 140     soft_tiles
# 150     soft_tiles
# 240     soft_tiles
# 253     soft_tiles
# 258     soft_tiles
# 291     soft_tiles
# 293     soft_tiles
# 298     soft_tiles
# 307     soft_tiles
# 321     soft_tiles
# 348     soft_tiles
# 370     soft_tiles
# 372     soft_tiles
# 406     soft_tiles
# 440     soft_tiles
# 445     soft_tiles
# 452     soft_tiles
#            ...
# 6646         empty
# 6693         empty
# 6706         empty
# 6775         empty
# 6818         empty
# 6867         empty
# 6886         empty
# 6890         empty
# 6894         empty
# 6923         empty
# 6961         empty
# 7035         empty
# 7037         empty
# 7041         empty
# 7045         empty
# 7060         empty
# ...

# %%
data['surface']
# Out:
# 0                fine_concrete
# 1                     concrete
# 2                     concrete
# 3                     concrete
# 4                   soft_tiles
# 5                        tiled
# 6                     soft_pvc
# 7                     concrete
# 8       hard_tiles_large_space
# 9                        tiled
# 10                    soft_pvc
# 11                       tiled
# 12                      carpet
# 13                      carpet
# 14                    concrete
# 15                      carpet
# 16                      carpet
# 17                  soft_tiles
# 18                       tiled
# 19                  soft_tiles
# 20                       tiled
# 21      hard_tiles_large_space
# 22                  soft_tiles
# 23                       tiled
# 24                  soft_tiles
# 25                  soft_tiles
# 26               fine_concrete
# 27                  hard_tiles
# 28                       tiled
# 29      hard_tiles_large_space
# ...

# %%
data[data['run_id']==0]
# Out:
#       series_id     surface  run_id  run_pos
# 19           19  soft_tiles       0        0
# 24           24  soft_tiles       0       25
# 30           30  soft_tiles       0       19
# 31           31  soft_tiles       0       43
# 52           52  soft_tiles       0       26
# 80           80  soft_tiles       0       17
# 88           88  soft_tiles       0        6
# 106         106  soft_tiles       0       83
# 114         114  soft_tiles       0       61
# 129         129  soft_tiles       0       49
# 135         135  soft_tiles       0       48
# 136         136  soft_tiles       0       78
# 137         137  soft_tiles       0       10
# 140         140  soft_tiles       0       92
# 150         150  soft_tiles       0       13
# 240         240  soft_tiles       0       84
# 253         253  soft_tiles       0       15
# 258         258  soft_tiles       0       96
# 291         291  soft_tiles       0       80
# 293         293  soft_tiles       0       34
# ...
